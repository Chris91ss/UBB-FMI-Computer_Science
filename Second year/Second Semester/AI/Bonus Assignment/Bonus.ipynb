# %%
Task: 

Use any resources (images, networks, CNNs, LLMs, Copilot, ChatGPT, etc.) to create an AI system that classifies 
in real time in the video stream from the webcam the owner of the laptop, 
the owner's pet (if you don't have a pet, borrow one), or if there is another person or nobody. 

Your solution should respect ETHICAL guidelines and prioritize user privacy.
It is essential to ensure that any data collected during this classification process is handled securely 
and with the explicit consent of the individuals involved. Moreover, the system should be designed to operate transparently, 
allowing users to understand how their data is used and providing options for them to opt out if they choose.

# %%
pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (0.10.21)
# Requirement already satisfied: opencv-python in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (4.10.0)
# Requirement already satisfied: absl-py in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (2.2.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (24.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (0.6.1)
# Requirement already satisfied: jaxlib in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (0.6.1)
# Requirement already satisfied: matplotlib in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: numpy<2 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (4.25.7)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt_einsum in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from jax->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\chris\anaconda3\envs\ailab\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import numpy as np

mp_face_detection = mp.solutions.face_detection
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

face_detection = mp_face_detection.FaceDetection(model_selection=0, min_detection_confidence=0.5)
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1)

owner_embedding = None
owner_img = cv2.imread("owner.jpg")
if owner_img is not None:
    owner_rgb = cv2.cvtColor(owner_img, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(owner_rgb)
    if results.multi_face_landmarks:
        landmarks = results.multi_face_landmarks[0].landmark
        owner_embedding = np.array([[lm.x, lm.y] for lm in landmarks]).flatten()
        owner_embedding -= np.mean(owner_embedding)
        owner_embedding /= np.linalg.norm(owner_embedding)
    else:
        print("Warning: No landmarks found in 'owner.jpg'")
else:
    print("Warning: 'owner.jpg' not found")

orb = cv2.ORB_create()
pet_img = cv2.imread("pet.jpg", cv2.IMREAD_GRAYSCALE)
pet_kp, pet_des = orb.detectAndCompute(pet_img, None) if pet_img is not None else (None, None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

def extract_face_embedding(frame):
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(rgb)
    if results.multi_face_landmarks:
        landmarks = results.multi_face_landmarks[0].landmark
        embedding = np.array([[lm.x, lm.y] for lm in landmarks]).flatten()
        embedding -= np.mean(embedding)
        norm = np.linalg.norm(embedding)
        if norm == 0:
            return None
        return embedding / norm
    return None

def is_owner_face(current_embedding):
    if owner_embedding is None or current_embedding is None:
        return False
    similarity = np.dot(owner_embedding, current_embedding)
    return similarity > 0.95

def is_pet_present(frame):
    if pet_des is None:
        return False
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    kp, des = orb.detectAndCompute(gray, None)
    if des is None:
        return False
    matches = bf.match(pet_des, des)
    good_matches = [m for m in matches if m.distance < 50]
    return len(good_matches) > 10  # tune threshold

cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    if not ret:
        break

    label = "Nobody"
    detections = face_detection.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).detections
    if detections:
        label = "Other Person"
        current_embedding = extract_face_embedding(frame)
        if is_owner_face(current_embedding):
            label = "Owner"
    elif is_pet_present(frame):
        label = "Pet"

    cv2.putText(frame, label, (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 0, 0), 2)
    if detections:
        for d in detections:
            mp_drawing.draw_detection(frame, d)

    cv2.imshow("Webcam Classification", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
